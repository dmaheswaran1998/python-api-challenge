# %%
#importing the relevant modules 

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress


#ADD SENTENCES AFTER EACH SCATTER PLOT
#

# %%
# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %%
# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
#Perform a weather check on each city using a series of successive API calls.
#Include a print log of each city as it'sbeing processed (with the city number and city name).

# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient countlen(cities)

# %%
#creating a new dataframe 
cities_pd=pd.DataFrame({"City": cities})
cities_pd.count()
# Out:
# City    593
# dtype: int64

# %%
#adding new columns to the dataframe 
cities_pd["Lat"] = ""
cities_pd["Lng"] = ""
cities_pd["Max Temp"] = ""
cities_pd["Humidity"] = ""
cities_pd["Cloud Coverage"] = ""
cities_pd["Wind Speed"] = ""
cities_pd["Country"] = ""
cities_pd["Date"] = ""

# %%
#multiple soccuessive API calls, the print log loops back at 49, 
#similar to what was shown in the sample output
set=1
number=0

for index, row in cities_pd.iterrows():
    url = "http://api.openweathermap.org/data/2.5/weather?"
    place = row["City"]
    units = "imperial"
    query_url = f"{url}appid={weather_api_key}&units={units}&q={place}"
    weather_data=requests.get(query_url)
    response=weather_data.json()
    
    
   
    
    try:
        print(f'Processing Record {number} of Set {set} | {place}')
        cities_pd.loc[index, "Lat"] =(response['coord']['lat'])
        cities_pd.loc[index, "Lng"] =(response['coord']['lon'])
        cities_pd.loc[index, "Max Temp"] = (response['main']['temp_max'])
        cities_pd.loc[index, "Humidity"] = (response['main']['humidity'])
        cities_pd.loc[index, "Cloud Coverage"] = (response['clouds']['all'])
        cities_pd.loc[index, "Wind Speed"] = (response['wind']['speed'])
        cities_pd.loc[index, "Country"] = (response['sys']['country'])
        cities_pd.loc[index, "Date"] = (response['dt'])
    
    except (KeyError, IndexError):
        print("City not found. Skipping.")
    
    
    number=number +1
    
    if number==50:
        number=0
        set=set + 1
# Out:
# Processing Record 0 of Set 1 | lubao
# Processing Record 1 of Set 1 | yellowknife
# Processing Record 2 of Set 1 | katsuura
# Processing Record 3 of Set 1 | vostok
# Processing Record 4 of Set 1 | pisco
# Processing Record 5 of Set 1 | bluff
# Processing Record 6 of Set 1 | ribeira grande
# Processing Record 7 of Set 1 | new norfolk
# Processing Record 8 of Set 1 | antalaha
# Processing Record 9 of Set 1 | alofi
# Processing Record 10 of Set 1 | saskylakh
# Processing Record 11 of Set 1 | ilulissat
# Processing Record 12 of Set 1 | taolanaro
# City not found. Skipping.
# Processing Record 13 of Set 1 | belushya guba
# City not found. Skipping.
# Processing Record 14 of Set 1 | bur gabo
# City not found. Skipping.
# Processing Record 15 of Set 1 | arraial do cabo
# Processing Record 16 of Set 1 | pangoa
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | takhtamygda
# Processing Record 19 of Set 1 | ostrovnoy
# Processing Record 20 of Set 1 | srivardhan
# Processing Record 21 of Set 1 | hobart
# Processing Record 22 of Set 1 | saint-philippe
# Processing Record 23 of Set 1 | hithadhoo
# Processing Record 24 of Set 1 | sur
# Processing Record 25 of Set 1 | ust-kan
# Processing Record 26 of Set 1 | chokurdakh
# Processing Record 27 of Set 1 | cape town
# City not found. Skipping.
# Processing Record 15 of Set 4 | ondorhaan
# City not found. Skipping.
# Processing Record 16 of Set 4 | palu
# Processing Record 17 of Set 4 | nioro
# Processing Record 18 of Set 4 | port macquarie
# Processing Record 19 of Set 4 | caravelas
# Processing Record 20 of Set 4 | barentsburg
# City not found. Skipping.
# Processing Record 21 of Set 4 | marystown
# Processing Record 22 of Set 4 | illoqqortoormiut
# City not found. Skipping.
# Processing Record 23 of Set 4 | raduzhnyy
# Processing Record 24 of Set 4 | lebu
# Processing Record 25 of Set 4 | mariakani
# Processing Record 26 of Set 4 | kapaa
# Processing Record 27 of Set 4 | la rioja
# Processing Record 28 of Set 4 | leningradskiy
# Processing Record 29 of Set 4 | raudeberg
# Processing Record 30 of Set 4 | saint-pierre
# Processing Record 31 of Set 4 | myszkow
# Processing Record 32 of Set 4 | klaksvik
# Processing Record 33 of Set 4 | namatanai
# Processing Record 34 of Set 4 | samoylovka
# Processing Record 35 of Set 4 | marawi
# Processing Record 36 of Set 4 | amga
# Processing Record 37 of Set 4 | celestun
# Processing Record 38 of Set 4 | san patricio
# Processing Record 39 of Set 4 | lesnikovo
# Processing Record 40 of Set 4 | tacuarembo
# Processing Record 41 of Set 4 | kodiak
# Processing Record 42 of Set 4 | killybegs
# Processing Record 43 of Set 4 | moose factory
# Processing Record 44 of Set 4 | tasiilaq
# Processing Record 45 of Set 4 | yinchuan
# Processing Record 46 of Set 4 | balakovo
# Processing Record 47 of Set 4 | provideniya
# Processing Record 48 of Set 4 | longyearbyen
# Processing Record 49 of Set 4 | faya
# Processing Record 0 of Set 5 | coihaique
# Processing Record 1 of Set 5 | ulladulla
# Processing Record 2 of Set 5 | gangotri
# City not found. Skipping.
# Processing Record 3 of Set 5 | nikolskoye
# Processing Record 4 of Set 5 | pontes e lacerda
# Processing Record 5 of Set 5 | ruatoria
# City not found. Skipping.
# Processing Record 6 of Set 5 | mount gambier
# Processing Record 7 of Set 5 | pierre
# Processing Record 8 of Set 5 | isangel
# Processing Record 9 of Set 5 | saint george
# Processing Record 10 of Set 5 | bambous virieux
# Processing Record 11 of Set 5 | saldanha
# Processing Record 12 of Set 5 | thompson
# Processing Record 13 of Set 5 | cabo san lucas
# Processing Record 14 of Set 5 | fort saint john
# City not found. Skipping.
# Processing Record 15 of Set 5 | san pedro
# Processing Record 16 of Set 5 | hobyo
# Processing Record 17 of Set 5 | mamallapuram
# Processing Record 18 of Set 5 | faanui
# Processing Record 19 of Set 5 | mbanza-ngungu
# Processing Record 20 of Set 5 | zambezi
# Processing Record 21 of Set 5 | kavaratti
# Processing Record 22 of Set 5 | coahuayana
# Processing Record 23 of Set 5 | wulanhaote
# City not found. Skipping.
# Processing Record 24 of Set 5 | ixtapa
# Processing Record 25 of Set 5 | grass valley
# Processing Record 26 of Set 5 | axim
# Processing Record 27 of Set 5 | svetlogorsk
# Processing Record 28 of Set 5 | payo
# Processing Record 29 of Set 5 | port lincoln
# Processing Record 30 of Set 5 | belmonte
# Processing Record 31 of Set 5 | sao filipe
# Processing Record 32 of Set 5 | idstein
# Processing Record 33 of Set 5 | walvis bay
# Processing Record 34 of Set 5 | skjervoy
# Processing Record 35 of Set 5 | san policarpo
# Processing Record 36 of Set 5 | china
# Processing Record 37 of Set 5 | miri
# Processing Record 38 of Set 5 | vao
# Processing Record 39 of Set 5 | kanye
# Processing Record 40 of Set 5 | sarkikaraagac
# Processing Record 41 of Set 5 | carutapera
# Processing Record 42 of Set 5 | arlit
# Processing Record 43 of Set 5 | port-gentil
# Processing Record 44 of Set 5 | smithers
# Processing Record 45 of Set 5 | hualmay
# Processing Record 46 of Set 5 | manta
# Processing Record 47 of Set 5 | stade
# Processing Record 48 of Set 5 | panacan
# Processing Record 49 of Set 5 | marcona
# City not found. Skipping.
# Processing Record 0 of Set 6 | kingman
# Processing Record 1 of Set 6 | porterville
# Processing Record 2 of Set 6 | ylivieska
# Processing Record 3 of Set 6 | lyuban
# Processing Record 4 of Set 6 | amderma
# City not found. Skipping.
# Processing Record 5 of Set 6 | biak
# Processing Record 6 of Set 6 | tyukhtet
# Processing Record 7 of Set 6 | porto novo
# Processing Record 8 of Set 6 | binghamton
# Processing Record 9 of Set 6 | komsomolskiy
# Processing Record 10 of Set 6 | chimbote
# Processing Record 11 of Set 6 | zhigansk
# Processing Record 12 of Set 6 | hakkari
# Processing Record 13 of Set 6 | troitskoye
# Processing Record 14 of Set 6 | heishan
# Processing Record 15 of Set 6 | yuci
# Processing Record 16 of Set 6 | stekolnyy
# City not found. Skipping.
# Processing Record 17 of Set 6 | sechura
# Processing Record 18 of Set 6 | dubbo
# Processing Record 19 of Set 6 | paita
# Processing Record 20 of Set 6 | plettenberg bay
# Processing Record 21 of Set 6 | amapa
# Processing Record 22 of Set 6 | ketchikan
# Processing Record 23 of Set 6 | along
# Processing Record 24 of Set 6 | valleyview
# Processing Record 25 of Set 6 | gizo
# Processing Record 26 of Set 6 | mitsamiouli
# Processing Record 27 of Set 6 | geraldton
# Processing Record 28 of Set 6 | sinnamary
# Processing Record 29 of Set 6 | ossora
# Processing Record 30 of Set 6 | misratah
# Processing Record 31 of Set 6 | rungata
# City not found. Skipping.
# Processing Record 32 of Set 6 | panubigan
# Processing Record 33 of Set 6 | le vauclin
# Processing Record 34 of Set 6 | santa maria
# Processing Record 35 of Set 6 | lincoln
# Processing Record 36 of Set 6 | agadez
# Processing Record 37 of Set 6 | the valley
# Processing Record 38 of Set 6 | dikson
# Processing Record 39 of Set 6 | bar
# Processing Record 40 of Set 6 | kamenskoye
# City not found. Skipping.
# Processing Record 41 of Set 6 | zhashkiv
# Processing Record 42 of Set 6 | havelock
# Processing Record 43 of Set 6 | ferrol
# Processing Record 44 of Set 6 | saucillo
# Processing Record 45 of Set 6 | koumra
# Processing Record 46 of Set 6 | anadyr
# Processing Record 47 of Set 6 | rio gallegos
# Processing Record 48 of Set 6 | lady frere
# Processing Record 49 of Set 6 | puerto del rosario
# Processing Record 0 of Set 7 | cavalcante
# Processing Record 1 of Set 7 | gopalpur
# Processing Record 2 of Set 7 | sakaiminato
# Processing Record 3 of Set 7 | lahaina
# Processing Record 4 of Set 7 | sitka
# Processing Record 5 of Set 7 | marquette
# Processing Record 6 of Set 7 | ziniare
# Processing Record 7 of Set 7 | buchanan
# Processing Record 8 of Set 7 | harper
# Processing Record 9 of Set 7 | itatinga
# Processing Record 10 of Set 7 | lolua
# City not found. Skipping.
# Processing Record 11 of Set 7 | nagato
# Processing Record 12 of Set 7 | salalah
# Processing Record 13 of Set 7 | pathein
# Processing Record 14 of Set 7 | tsihombe
# City not found. Skipping.
# Processing Record 15 of Set 7 | bandarbeyla
# Processing Record 16 of Set 7 | hongjiang
# Processing Record 17 of Set 7 | hovd
# Processing Record 18 of Set 7 | prince george
# Processing Record 19 of Set 7 | sentyabrskiy
# City not found. Skipping.
# Processing Record 20 of Set 7 | waddan
# Processing Record 21 of Set 7 | kasongo-lunda
# Processing Record 22 of Set 7 | sapiranga
# Processing Record 23 of Set 7 | tura
# Processing Record 24 of Set 7 | santo antonio do ica
# Processing Record 25 of Set 7 | ejido hermosillo
# Processing Record 26 of Set 7 | te anau
# Processing Record 27 of Set 7 | saint anthony
# Processing Record 28 of Set 7 | otane
# Processing Record 29 of Set 7 | karratha
# Processing Record 30 of Set 7 | cockenzie
# Processing Record 31 of Set 7 | felidhoo
# City not found. Skipping.
# Processing Record 32 of Set 7 | praia da vitoria
# Processing Record 33 of Set 7 | santa cruz
# Processing Record 34 of Set 7 | sioux lookout
# Processing Record 35 of Set 7 | nuuk
# Processing Record 36 of Set 7 | itarema
# Processing Record 37 of Set 7 | noumea
# Processing Record 38 of Set 7 | nome
# Processing Record 39 of Set 7 | sabang
# Processing Record 40 of Set 7 | sorland
# Processing Record 41 of Set 7 | poso
# Processing Record 42 of Set 7 | grimshaw
# Processing Record 43 of Set 7 | ngunguru
# Processing Record 44 of Set 7 | khasan
# Processing Record 45 of Set 7 | ceres
# Processing Record 46 of Set 7 | mosquera
# Processing Record 47 of Set 7 | altamont
# Processing Record 48 of Set 7 | grand gaube
# Processing Record 49 of Set 7 | guanica
# Processing Record 0 of Set 8 | dingle
# Processing Record 1 of Set 8 | anloga
# Processing Record 2 of Set 8 | hajnowka
# Processing Record 3 of Set 8 | hasaki
# Processing Record 4 of Set 8 | port hedland
# Processing Record 5 of Set 8 | riyadh
# Processing Record 6 of Set 8 | talah
# City not found. Skipping.
# Processing Record 7 of Set 8 | sola
# Processing Record 8 of Set 8 | tuckahoe
# Processing Record 9 of Set 8 | yerofey pavlovich
# Processing Record 10 of Set 8 | cayenne
# Processing Record 11 of Set 8 | los llanos de aridane
# Processing Record 12 of Set 8 | bathsheba
# Processing Record 13 of Set 8 | zyryanka
# Processing Record 14 of Set 8 | bad aussee
# Processing Record 15 of Set 8 | bolshoye sorokino
# City not found. Skipping.
# Processing Record 16 of Set 8 | kieta
# Processing Record 37 of Set 9 | neiafu
# Processing Record 38 of Set 9 | dhidhdhoo
# Processing Record 39 of Set 9 | goma
# Processing Record 40 of Set 9 | necochea
# Processing Record 41 of Set 9 | kovdor
# Processing Record 42 of Set 9 | doha
# Processing Record 43 of Set 9 | mount isa
# Processing Record 44 of Set 9 | fengcheng
# Processing Record 45 of Set 9 | anjad
# Processing Record 46 of Set 9 | roma
# Processing Record 47 of Set 9 | portland
# Processing Record 48 of Set 9 | sorong
# Processing Record 49 of Set 9 | itarantim
# Processing Record 0 of Set 10 | ilo
# Processing Record 1 of Set 10 | lyubinskiy
# Processing Record 2 of Set 10 | ancud
# Processing Record 3 of Set 10 | harwich
# Processing Record 4 of Set 10 | tuatapere
# Processing Record 5 of Set 10 | killarney
# Processing Record 6 of Set 10 | uray
# Processing Record 7 of Set 10 | hami
# Processing Record 8 of Set 10 | phan thiet
# Processing Record 9 of Set 10 | buala
# Processing Record 10 of Set 10 | hendijan
# City not found. Skipping.
# Processing Record 11 of Set 10 | bargal
# City not found. Skipping.
# Processing Record 12 of Set 10 | ilhabela
# Processing Record 13 of Set 10 | imbituba
# Processing Record 14 of Set 10 | tungor
# Processing Record 15 of Set 10 | colquiri
# Processing Record 16 of Set 10 | boa vista
# Processing Record 17 of Set 10 | maridi
# Processing Record 18 of Set 10 | ayan
# Processing Record 19 of Set 10 | bubaque
# Processing Record 20 of Set 10 | houma
# Processing Record 21 of Set 10 | sulangan
# Processing Record 22 of Set 10 | opole
# Processing Record 23 of Set 10 | alice springs
# Processing Record 24 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 25 of Set 10 | tonami
# Processing Record 26 of Set 10 | rockport
# Processing Record 27 of Set 10 | haines junction
# Processing Record 28 of Set 10 | makushino
# Processing Record 29 of Set 10 | dawlatabad
# Processing Record 30 of Set 10 | solnechnyy
# Processing Record 31 of Set 10 | la reforma
# Processing Record 32 of Set 10 | esperance
# Processing Record 33 of Set 10 | kaeo
# Processing Record 34 of Set 10 | krasnousolskiy
# City not found. Skipping.
# Processing Record 35 of Set 10 | warrnambool
# Processing Record 36 of Set 10 | samusu
# City not found. Skipping.
# Processing Record 37 of Set 10 | vila velha
# Processing Record 38 of Set 10 | nabire
# Processing Record 39 of Set 10 | nacogdoches
# Processing Record 40 of Set 10 | marsh harbour
# Processing Record 41 of Set 10 | fukue
# Processing Record 42 of Set 10 | taoudenni
# Processing Record 43 of Set 10 | rayagada
# Processing Record 44 of Set 10 | kuytun
# Processing Record 45 of Set 10 | agucadoura
# Processing Record 46 of Set 10 | novopskov
# Processing Record 47 of Set 10 | barcelos
# Processing Record 48 of Set 10 | sahrak
# City not found. Skipping.
# Processing Record 49 of Set 10 | levelland
# Processing Record 0 of Set 11 | diego de almagro
# Processing Record 1 of Set 11 | nara
# Processing Record 2 of Set 11 | port-cartier
# Processing Record 3 of Set 11 | avila
# Processing Record 4 of Set 11 | sechelt
# Processing Record 5 of Set 11 | tezu
# Processing Record 6 of Set 11 | shahpur
# Processing Record 7 of Set 11 | vaitupu
# City not found. Skipping.
# Processing Record 8 of Set 11 | siaya
# Processing Record 9 of Set 11 | la orilla
# Processing Record 10 of Set 11 | kalianget
# Processing Record 11 of Set 11 | maningrida
# Processing Record 12 of Set 11 | aykhal
# Processing Record 13 of Set 11 | constitucion
# Processing Record 14 of Set 11 | jalu
# Processing Record 15 of Set 11 | kaili
# Processing Record 16 of Set 11 | balabac
# Processing Record 17 of Set 11 | mahibadhoo
# Processing Record 18 of Set 11 | ambon
# Processing Record 19 of Set 11 | kruisfontein
# Processing Record 20 of Set 11 | susanino
# Processing Record 21 of Set 11 | bealanana
# Processing Record 22 of Set 11 | krasnyy chikoy
# Processing Record 23 of Set 11 | xuddur
# Processing Record 24 of Set 11 | college
# Processing Record 25 of Set 11 | kingaroy
# Processing Record 26 of Set 11 | tahta
# Processing Record 27 of Set 11 | tignere
# Processing Record 28 of Set 11 | tanete
# Processing Record 29 of Set 11 | clarence town
# Processing Record 30 of Set 11 | fernie
# Processing Record 31 of Set 11 | kungurtug
# Processing Record 32 of Set 11 | whitianga
# Processing Record 33 of Set 11 | tocopilla
# Processing Record 34 of Set 11 | carballo
# Processing Record 35 of Set 11 | valday
# Processing Record 36 of Set 11 | muros
# Processing Record 37 of Set 11 | aasiaat
# Processing Record 38 of Set 11 | dodola
# Processing Record 39 of Set 11 | livramento
# Processing Record 40 of Set 11 | alta floresta
# Processing Record 41 of Set 11 | muskegon
# Processing Record 42 of Set 11 | huarmey
# Processing Record 43 of Set 11 | nouadhibou
# Processing Record 44 of Set 11 | naberera
# Processing Record 45 of Set 11 | bereda
# Processing Record 46 of Set 11 | bongandanga
# Processing Record 47 of Set 11 | sakakah
# Processing Record 48 of Set 11 | karaul
# City not found. Skipping.
# Processing Record 49 of Set 11 | husavik
# Processing Record 0 of Set 12 | lakes entrance
# Processing Record 1 of Set 12 | russell
# Processing Record 2 of Set 12 | nago
# Processing Record 3 of Set 12 | udgir
# Processing Record 4 of Set 12 | abancay
# Processing Record 5 of Set 12 | byron bay
# Processing Record 6 of Set 12 | lucea
# Processing Record 7 of Set 12 | koping
# Processing Record 8 of Set 12 | inuvik
# Processing Record 9 of Set 12 | sunbury
# Processing Record 10 of Set 12 | majene
# Processing Record 11 of Set 12 | north augusta
# Processing Record 12 of Set 12 | gannan
# Processing Record 13 of Set 12 | chibuto
# Processing Record 14 of Set 12 | labrea
# Processing Record 15 of Set 12 | oksfjord
# Processing Record 16 of Set 12 | asosa
# Processing Record 17 of Set 12 | kenitra
# Processing Record 18 of Set 12 | houston
# Processing Record 19 of Set 12 | ust-nera
# Processing Record 20 of Set 12 | miandrivazo
# Processing Record 21 of Set 12 | camacha
# Processing Record 22 of Set 12 | minot
# Processing Record 23 of Set 12 | koungou
# Processing Record 24 of Set 12 | lorengau
# Processing Record 25 of Set 12 | sukhoy log
# Processing Record 26 of Set 12 | talakan
# Processing Record 27 of Set 12 | martapura
# Processing Record 28 of Set 12 | orizatlan
# Processing Record 29 of Set 12 | gillette
# Processing Record 30 of Set 12 | mantua
# Processing Record 31 of Set 12 | bekhteyevka
# Processing Record 32 of Set 12 | pembroke
# Processing Record 33 of Set 12 | libano
# Processing Record 34 of Set 12 | hesla
# Processing Record 35 of Set 12 | fort nelson
# Processing Record 36 of Set 12 | andenes
# Processing Record 37 of Set 12 | jacareacanga
# Processing Record 38 of Set 12 | igarka
# Processing Record 39 of Set 12 | lodwar
# Processing Record 40 of Set 12 | san quintin
# Processing Record 41 of Set 12 | bardiyah
# Processing Record 42 of Set 12 | lingsugur

# %%
#saving oinitial utput to csv 
cities_pd.to_csv("Cities_Output.csv")


#getting rid of rows wuth blank output
cities_clean=cities_pd.loc[cities_pd["Lat"]!=""]

cities_clean=pd.DataFrame(cities_clean)

#mapping as float variable for all variables

cities_clean['Humidity'] = cities_clean['Humidity'].astype(float)

# %%
#Checking for the humidity

cities_humid=cities_clean.loc[cities_clean["Humidity"]>100]
cities_humid
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloud Coverage, Wind Speed, Country, Date]
# Index: []

# %%
#no cities greater than 100% humidity so map other variables to a float  

cities_clean['Lng'] = cities_clean['Lng'].astype(float)
cities_clean['Lat'] = cities_clean['Lat'].astype(float)
cities_clean['Max Temp'] = cities_clean['Max Temp'].astype(float)
cities_clean['Cloud Coverage'] = cities_clean['Cloud Coverage'].astype(float)
cities_clean['Wind Speed'] = cities_clean['Wind Speed'].astype(float)
cities_clean['Wind Speed'] = cities_clean['Wind Speed'].astype(float)


#Mapping clean file to csv 
cities_clean.to_csv("Cities_Output2.csv")

# %%
#Latitude vs  Max Temperature plot

fig, ax = plt.subplots()
cities_clean.plot(kind='scatter', x='Lat', y='Max Temp', ax=ax, edgecolors='b')
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperature (Farenheit)")
plt.title("City Latitude vs Max Temperature" )

# Turn on the grid
ax.grid()
plt.savefig('Lat_MaxTemp.png')

plt.show()

# %% [markdown]
# The code above compares the latitude of cities with their maximum temperatures. As shown from the scatterplot above, the relationship between latititude and maximum temperature has a parabolic shape. In other words, cities with low and high latititudes tend to have low maximum temperatures, while cities with a latitude closer to 0 have a higher maximum temperature.  This makes intutive sense, as cities with a latitiude close to 0 would be closer to the equator and therefore have a higher maximum temperature.

# %%
#Latitude vs Humidity Plot 
fig, ax = plt.subplots()
cities_clean.plot(kind='scatter', x='Lat', y='Humidity', ax=ax, edgecolors='b')
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs Humidity" )


# Turn on the grid
ax.grid()

plt.savefig('Lat_Humidity.png')

plt.show()

# %% [markdown]
# The code above compares the latitude of cities with their maximum Humidity. As shown from the scatterplot above, there is no strong correlation between latitutde and humidity. However, it is noted that ALMOST all cities that are closs to the equator (between -20 and 20 latitude) have humidity higher than 60%. This also makes sense as these cities are hotter (as shown in the graph above) and therefore more water vapor can be in the air without condensing, making these places more humid.

# %%
#Latitude vs Cloudiness Plot
fig, ax = plt.subplots()
cities_clean.plot(kind='scatter', x='Lat', y='Cloud Coverage', ax=ax, edgecolors='b')
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("City Latitude vs Cloudiness" )
# Turn on the grid
ax.grid()

plt.savefig('Lat_Cloud.png')

plt.show()

# %% [markdown]
# This scatterplot depicts the relationship between Latitude and Cloudiness. While once again there does not seem to be a strong correlation between Latitude and Cloudiness,  the most common cloudiness values for cities seem to be 0, 40, approximately 80 and 100.  This may bbe because latitude does not influence the cloudiness of cities, or it may just be an anomlay based on they day the data was gathered.

# %%
#Latitude vs Wind Speed Plot 
fig, ax = plt.subplots()
cities_clean.plot(kind='scatter', x='Lat', y='Wind Speed', ax=ax, edgecolors='b')
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("City Latitude vs Wind Speed" )
# Turn on the grid
ax.grid()

plt.savefig('Lat_Wind.png')

plt.show()

# %% [markdown]
# The scatterplot shows the relationship between Latitude and Wind speed. Once again, there does not seem to be a clear relationship between the two variables. Thus, once again latitude does not seem to influence wind speed.

# %%
#Northern Hemisphere vs Southern Hemisphere database- created using the loc command 
northern_hemisphere=cities_clean.loc[cities_clean["Lat"]>=0]
southern_hemisphere=cities_clean.loc[cities_clean["Lat"]<0]

# %%
#Northern Hemisphere Lat v Max Temp

x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values) 

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Line equation is {line_eq}")
print(f'The correlation coefficient is {rvalue}')

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-",label=line_eq)
plt.legend(fontsize=9)

plt.annotate(line_eq,(60,1),fontsize=30,color="red")
plt.xlabel('Latitude')
plt.ylabel(' Temperature in F')
plt.title('Northern Hemisphere Latitude vs Max Temperature')
plt.savefig('North_Lat_Max.png')

plt.show()
# Out:
# Line equation is y = -0.48x + 88.7
# The correlation coefficient is -0.6829555842223517

# %%
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values) 

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Line equation is {line_eq}")
print(f'The correlation coefficient is {rvalue}')
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-",label=line_eq)
plt.legend(fontsize=9)

plt.annotate(line_eq,(47,12),fontsize=30,color="red")
plt.xlabel('Latitude')
plt.ylabel('Temperature in F')
plt.title('Southern Hemisphere Latitude vs Max Temperature')
plt.savefig('South_Lat_Max.png')

plt.show()
# Out:
# Line equation is y = 0.8x + 80.46
# The correlation coefficient is 0.7459737462085633

# %% [markdown]
# As shown by the scatterplots and linear regression model above, in the Northern Hemisphere there is a reasonably strong negative correlation (-0.71) between latitiude and maximum temperature while in the Southern Hemisphere there is a reasonably strong positive correlation (0.80) between latitude and maximum temperature. This is fairly intutive, as cities that are closer to the equator (latitiude of 0), would usually be hotter and have a higher maximum temperature. As cities become further away from the equator, their maximum temperature drops. This relationship was similarly seen in the latitude and maximum temperature scatterplot above.

# %%
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values) 

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Line equation is {line_eq}")
print(f'The correlation coefficient is {rvalue}')
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-",label=line_eq)
plt.legend(fontsize=9)

plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere Latitude vs Humidity')
plt.savefig('Northern_Lat_Humidity.png')

plt.show()
# Out:
# Line equation is y = -0.04x + 71.24
# The correlation coefficient is -0.03991137533239535

# %%
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values) 

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Line equation is {line_eq}")
print(f'The correlation coefficient is {rvalue}')
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-",label=line_eq)
plt.legend(fontsize=9)

plt.annotate(line_eq,(15,12),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere Latitude vs Humidity')
plt.savefig('Southern_Lat_Humidity.png')

plt.show()
# Out:
# Line equation is y = 0.09x + 73.88
# The correlation coefficient is 0.05883642697179015

# %% [markdown]
# As shown by the scatterplots above, there is a slightly negative relationship between latitude and humidity in both the Northern and Southern Hemisphere. However, the correlation between latitiude and humidity is weak in both the Northern and Southern Hemisphere, at -0.09 and -0.127 respectively. This is similarly supported by the scatterplot of humidity and latitidue above where not clear correlation was shown between the two variables.

# %%
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Cloud Coverage']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values) 

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Line equation is {line_eq}")
print(f'The correlation coefficient is {rvalue}')
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-",label=line_eq)
plt.legend(fontsize=9)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Northern Hemisphere Latitude vs Cloudiness')
plt.savefig('Northern_Lat_Cloud.png')

plt.show()
# Out:
# Line equation is y = 0.01x + 53.35
# The correlation coefficient is 0.006818125294495337

# %%
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Cloud Coverage']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values) 

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Line equation is {line_eq}")
print(f'The correlation coefficient is {rvalue}')
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-",label=line_eq)
plt.legend(fontsize=9)

plt.annotate(line_eq,(15,12),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Southern Hemisphere Latitude vs Cloudiness')
plt.savefig('Southern_Lat_Cloud.png')

plt.show()
# Out:
# Line equation is y = -0.27x + 43.43
# The correlation coefficient is -0.10075914981154471

# %% [markdown]
# The correlation between cloudiness and the latitiude in the Northern Hemipshere is almost 0. However, in the Southern hemisphere, the correlation is slightly stronger and negative (-0.17). The reason for this stronger correlation in the southern hemisphere compared to the Northern Hemisphere may be because of the time the measurements were taken.

# %%
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values) 

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Line equation is {line_eq}")
print(f'The correlation coefficient is {rvalue}')
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-",label=line_eq)
plt.legend(fontsize=9)


plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Northern Hemisphere Latitude vs Wind Speed')
plt.savefig('Northern_Lat_Wind.png')

plt.show()
# Out:
# Line equation is y = 0.0x + 7.37
# The correlation coefficient is 0.009657837870748151

# %%
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values) 

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Line equation is {line_eq}")
print(f'The correlation coefficient is {rvalue}')
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-",label=line_eq)
plt.legend(fontsize=9)


plt.annotate(line_eq,(5,20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Southern Hemisphere Latitude vs Wind Speed')
plt.savefig('Southern_Lat_Wind.png')
plt.show()
# Out:
# Line equation is y = 0.01x + 7.59
# The correlation coefficient is 0.017860280391621706

# %% [markdown]
# There does not seem to be a strong correlation between Wind speed and Latitude in both the Northern and Southern Hemisphere. The reason for this may be because Latitiude does not have an effect on wind speed in either Hemisphere. Similar results were supported by the earlier scatterplot of Latitiude vs Wind Speed.
